# %% [markdown]
# <img src="https://i.ytimg.com/vi/cUn01JYbpWo/maxresdefault.jpg">

# %% [markdown]
# ## Get all MVPS since 1991 and votes

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
years = list(range(1991, 2022))

# %%
# get the url with the year
url_start = "https://www.basketball-reference.com/awards/awards_{}.html"

for year in years: 
    url = url_start.format(year)
    data = requests.get(url)
    
    with open("mvp/{}.html".format(year), "w+") as f:
        f.write(data.text)

# %%
with open("mvp/1991.html", "r") as f:
    page = f.read()

# %%
soup = BeautifulSoup(page, "html.parser")

# %%
# remove the header of the table
soup.find('tr', class_="over_header").decompose()

# %%
# find the table
mvp_table = soup.find( id="mvp")

# %%
# test with 1991 mvp
mvp_1991 = pd.read_html(str(mvp_table))[0]
mvp_1991
# Out:
#    Rank             Player  Age   Tm  First  Pts Won  Pts Max  Share   G  \
# 0     1     Michael Jordan   27  CHI   77.0    891.0      960  0.928  82
# 1     2      Magic Johnson   31  LAL   10.0    497.0      960  0.518  79
# 2     3     David Robinson   25  SAS    6.0    476.0      960  0.496  82
# 3     4    Charles Barkley   27  PHI    2.0    222.0      960  0.231  67
# 4     5        Karl Malone   27  UTA    0.0    142.0      960  0.148  82
# 5     6      Clyde Drexler   28  POR    1.0     75.0      960  0.078  82
# 6     7      Kevin Johnson   24  PHO    0.0     32.0      960  0.033  77
# 7     8  Dominique Wilkins   31  ATL    0.0     29.0      960  0.030  81
# 8    9T         Larry Bird   34  BOS    0.0     25.0      960  0.026  60
# 9    9T       Terry Porter   27  POR    0.0     25.0      960  0.026  81
# 10   11      Patrick Ewing   28  NYK    0.0     20.0      960  0.021  81
# 11   12      John Stockton   28  UTA    0.0     15.0      960  0.016  82
# ...

# %%
# combine all the dataframes into one list of dataframes and 
dfs = []
for year in years:
    with open("mvp/{}.html".format(year)) as f:
        page = f.read()
    soup = BeautifulSoup(page, "html.parser")
    soup.find('tr', class_="over_header").decompose()
    mvp_table = soup.find( id="mvp")
    mvp = pd.read_html(str(mvp_table))[0]
    
    # add a column for the year
    mvp["Year"] = year
    
    dfs.append(mvp)

# %%
mvps = pd.concat(dfs)

# %%
# transform mvp file into a csv 

mvps.to_csv("mvps.csv")
mvps.head()
# Out:
#   Rank           Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0    1   Michael Jordan   27  CHI   77.0    891.0      960  0.928  82  37.0
# 1    2    Magic Johnson   31  LAL   10.0    497.0      960  0.518  79  37.1
# 2    3   David Robinson   25  SAS    6.0    476.0      960  0.496  82  37.7
# 3    4  Charles Barkley   27  PHI    2.0    222.0      960  0.231  67  37.3
# 4    5      Karl Malone   27  UTA    0.0    142.0      960  0.148  82  40.3
#
#    ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  Year
# 0  ...   6.0   5.5  2.7  1.0  0.539  0.312  0.851  20.3  0.321  1991
# 1  ...   7.0  12.5  1.3  0.2  0.477  0.320  0.906  15.4  0.251  1991
# 2  ...  13.0   2.5  1.5  3.9  0.552  0.143  0.762  17.0  0.264  1991
# 3  ...  10.1   4.2  1.6  0.5  0.570  0.284  0.722  13.4  0.258  1991
# 4  ...  11.8   3.3  1.1  1.0  0.527  0.286  0.770  15.5  0.225  1991
#
# [5 rows x 21 columns]

# %% [markdown]
# # Get Players Stats data

# %%
# get player stats for each year url and test with 1991

player_stats_url = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"

url = player_stats_url.format(1991)
data = requests.get(url)

# save the html file
with open ("player/1991.html", "w+") as f:
    f.write(data.text)

# %%
# install and initialize driver for selenium because the data is loaded with javascript 

driver = webdriver.Firefox(executable_path='/usr/bin/google-chrome')
year = 1991
url = player_stats_url.format(year)

driver.get(url)
driver.execute_script("windows.scrollTo(1, 1000)")
time.sleep(2)

html = driver.page_source
# Out:
# /tmp/ipykernel_435/1098447027.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path='/usr/bin/google-chrome')
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In [72], line 3
#       1 # install and initialize driver for selenium because the data is loaded with javascript
# ----> 3 driver = webdriver.Firefox(executable_path='/usr/bin/google-chrome')
#       4 year = 1991
#       5 url = player_stats_url.format(year)
#
# File ~/anaconda3/envs/school/lib/python3.10/site-packages/selenium/webdriver/firefox/webdriver.py:172, in WebDriver.__init__(self, firefox_profile, firefox_binary, capabilities, proxy, executable_path, options, service_log_path, service_args, service, desired_capabilities, log_path, keep_alive)
#     167 if not self.service:
#     168     self.service = Service(
# ...

# %%
year = 1991 
url = player_stats_url.format(year)

driver.get(url)
driver.execute_script("window.scrollTo(0, 10000)")
time.sleep(2)

html = driver.page_source
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 8
#       5 year = 1991
#       6 url = player_stats_url.format(year)
# ----> 8 driver.get(url)
#       9 driver.execute_script("window.scrollTo(0, 10000)")
#      10 time.sleep(2)
#
# NameError: name 'driver' is not defined
